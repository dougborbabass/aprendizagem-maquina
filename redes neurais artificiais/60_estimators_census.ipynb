# %%
import pandas as pd
base = pd.read_csv('census.csv')
base.head()
# Out:
#    age          workclass  final-weight   education  education-num  \
# 0   39          State-gov         77516   Bachelors             13
# 1   50   Self-emp-not-inc         83311   Bachelors             13
# 2   38            Private        215646     HS-grad              9
# 3   53            Private        234721        11th              7
# 4   28            Private        338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loos  hour-per-week  native-country  income
# 0          2174             0             40   United-States   <=50K
# 1             0             0             13   United-States   <=50K
# 2             0             0             40   United-States   <=50K
# 3             0             0             40   United-States   <=50K
# 4             0             0             40            Cuba   <=50K

# %%
base.income.unique()
# Out:
# array([' <=50K', ' >50K'], dtype=object)

# %%
def converte_classe(rotulo):
    if rotulo == ' >50K':
        return 1
    else:
        return 0

# %%
base.income = base.income.apply(converte_classe)

# %%
base.head()
# Out:
#    age          workclass  final-weight   education  education-num  \
# 0   39          State-gov         77516   Bachelors             13
# 1   50   Self-emp-not-inc         83311   Bachelors             13
# 2   38            Private        215646     HS-grad              9
# 3   53            Private        234721        11th              7
# 4   28            Private        338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loos  hour-per-week  native-country  income
# 0          2174             0             40   United-States       0
# 1             0             0             13   United-States       0
# 2             0             0             40   United-States       0
# 3             0             0             40   United-States       0
# 4             0             0             40            Cuba       0

# %%
x = base.drop('income', axis = 1)
y = base.income

# %%
x.head()
# Out:
#    age          workclass  final-weight   education  education-num  \
# 0   39          State-gov         77516   Bachelors             13
# 1   50   Self-emp-not-inc         83311   Bachelors             13
# 2   38            Private        215646     HS-grad              9
# 3   53            Private        234721        11th              7
# 4   28            Private        338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loos  hour-per-week  native-country
# 0          2174             0             40   United-States
# 1             0             0             13   United-States
# 2             0             0             40   United-States
# 3             0             0             40   United-States
# 4             0             0             40            Cuba

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: income, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_treinamento, x_teste, y_treinamento, y_teste = train_test_split(x, y, test_size = 0.3)

# %%
base.columns
# Out:
# Index(['age', 'workclass', 'final-weight', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loos', 'hour-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
import tensorflow as tf

# %%
base.workclass.unique()
# Out:
# array([' State-gov', ' Self-emp-not-inc', ' Private', ' Federal-gov',
#        ' Local-gov', ' ?', ' Self-emp-inc', ' Without-pay',
#        ' Never-worked'], dtype=object)

# %%
workclass = tf.feature_column.categorical_column_with_hash_bucket(key = 'workclass', hash_bucket_size = 100)
education = tf.feature_column.categorical_column_with_hash_bucket(key = 'education', hash_bucket_size = 100)
marital_status = tf.feature_column.categorical_column_with_hash_bucket(key = 'marital-status', hash_bucket_size = 100)
occupation = tf.feature_column.categorical_column_with_hash_bucket(key = 'occupation', hash_bucket_size = 100)
relationship = tf.feature_column.categorical_column_with_hash_bucket(key = 'relationship', hash_bucket_size = 100)
race = tf.feature_column.categorical_column_with_hash_bucket(key = 'race', hash_bucket_size = 100)
country = tf.feature_column.categorical_column_with_hash_bucket(key = 'native-country', hash_bucket_size = 100)

# %%
base.sex.unique()
# Out:
# array([' Male', ' Female'], dtype=object)

# %%
sex = tf.feature_column.categorical_column_with_vocabulary_list(key = 'sex', vocabulary_list = [' Male', ' Female'])

# %%
age = tf.feature_column.numeric_column(key = 'age')
final_weight = tf.feature_column.numeric_column(key = 'final-weight')
education_num = tf.feature_column.numeric_column(key = 'education-num')
capital_gain = tf.feature_column.numeric_column(key = 'capital-gain')
capital_loos = tf.feature_column.numeric_column(key = 'capital-loos')
hour = tf.feature_column.numeric_column(key = 'hour-per-week')

# %%
colunas = [age, workclass, final_weight, education, education_num, marital_status, occupation, relationship, race, sex,
          capital_gain, capital_loos, hour, country]

# %%
embedded_workclass = tf.feature_column.embedding_column(workclass, dimension = len(base.workclass.unique()))
embedded_education = tf.feature_column.embedding_column(education, dimension = len(base.education.unique()))
embedded_marital = tf.feature_column.embedding_column(marital_status, dimension = len(base['marital-status'].unique()))
embedded_occupation = tf.feature_column.embedding_column(occupation, dimension = len(base.occupation.unique()))
embedded_relationship = tf.feature_column.embedding_column(relationship, dimension = len(base.relationship.unique()))
embedded_race = tf.feature_column.embedding_column(race, dimension = len(base.race.unique()))
embedded_sex = tf.feature_column.embedding_column(sex, dimension = len(base.sex.unique()))
embedded_country = tf.feature_column.embedding_column(country, dimension = len(base['native-country'].unique()))

# %%
colunas_rna = [age, embedded_workclass, final_weight, embedded_education, education_num, 
               embedded_marital, embedded_occupation, embedded_relationship, embedded_race, embedded_sex,
               capital_gain, capital_loos, hour, embedded_country]

# %%
funcao_treinamento = tf.estimator.inputs.pandas_input_fn(x = x_treinamento, y = y_treinamento,
                                                        batch_size = 32, num_epochs = None, shuffle = False)

## hidden_units -> 2 camadas ocultas com 8 neuronios cada (atributos somado com a qtd de classes / 2)
classificador =  tf.estimator.DNNClassifier(hidden_units = [8, 8], feature_columns = colunas_rna, n_classes = 2)
classificador.train(input_fn = funcao_treinamento, steps = 10000)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\Douglas\AppData\Local\Temp\tmp2ybqnd2z
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\Douglas\\AppData\\Local\\Temp\\tmp2ybqnd2z', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x000001F878173EC8>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Entity <bound method _DNNModel.call of <tensorflow_estimator.python.estimator.canned.dnn._DNNModel object at 0x000001F879FAB848>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method _DNNModel.call of <tensorflow_estimator.python.estimator.canned.dnn._DNNModel object at 0x000001F879FAB848>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method _DNNModel.call of <tensorflow_estimator.python.estimator.canned.dnn._DNNModel object at 0x000001F879FAB848>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method _DNNModel.call of <tensorflow_estimator.python.estimator.canned.dnn._DNNModel object at 0x000001F879FAB848>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method DenseFeatures.call of <tensorflow.python.feature_column.feature_column_v2.DenseFeatures object at 0x000001F879F40A48>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method DenseFeatures.call of <tensorflow.python.feature_column.feature_column_v2.DenseFeatures object at 0x000001F879F40A48>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method DenseFeatures.call of <tensorflow.python.feature_column.feature_column_v2.DenseFeatures object at 0x000001F879F40A48>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method DenseFeatures.call of <tensorflow.python.feature_column.feature_column_v2.DenseFeatures object at 0x000001F879F40A48>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001F879B95148>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001F879B95148>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001F879B95148>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001F879B95148>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001F879B95888>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001F879B95888>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001F879B95888>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001F879B95888>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001F877E40408>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001F877E40408>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001F877E40408>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001F877E40408>>: AssertionError: Bad argument number for Name: 3, expecting 4
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into C:\Users\Douglas\AppData\Local\Temp\tmp2ybqnd2z\model.ckpt.
# INFO:tensorflow:loss = 186892.42, step = 1
# INFO:tensorflow:global_step/sec: 152.427
# INFO:tensorflow:loss = 2713.1401, step = 101 (0.659 sec)
# INFO:tensorflow:global_step/sec: 343.619
# INFO:tensorflow:loss = 1096.1211, step = 201 (0.291 sec)
# INFO:tensorflow:global_step/sec: 307.669
# INFO:tensorflow:loss = 310.68814, step = 301 (0.328 sec)
# INFO:tensorflow:global_step/sec: 294.096
# INFO:tensorflow:loss = 207.56013, step = 401 (0.337 sec)
# INFO:tensorflow:global_step/sec: 263.121
# INFO:tensorflow:loss = 161.32913, step = 501 (0.382 sec)
# INFO:tensorflow:global_step/sec: 267.378
# INFO:tensorflow:loss = 39.13512, step = 601 (0.372 sec)
# INFO:tensorflow:global_step/sec: 288.163
# INFO:tensorflow:loss = 52.77529, step = 701 (0.348 sec)
# INFO:tensorflow:global_step/sec: 227.242
# INFO:tensorflow:loss = 406.638, step = 801 (0.439 sec)
# INFO:tensorflow:global_step/sec: 254.451
# INFO:tensorflow:loss = 365.57, step = 901 (0.396 sec)
# INFO:tensorflow:global_step/sec: 222.701
# INFO:tensorflow:loss = 192.07494, step = 1001 (0.450 sec)
# INFO:tensorflow:global_step/sec: 224.702
# INFO:tensorflow:loss = 208.30432, step = 1101 (0.444 sec)
# INFO:tensorflow:global_step/sec: 224.199
# INFO:tensorflow:loss = 46.02317, step = 1201 (0.444 sec)
# INFO:tensorflow:global_step/sec: 230.398
# INFO:tensorflow:loss = 43.804237, step = 1301 (0.435 sec)
# INFO:tensorflow:global_step/sec: 219.764
# INFO:tensorflow:loss = 21.018078, step = 1401 (0.456 sec)
# INFO:tensorflow:global_step/sec: 221.713
# INFO:tensorflow:loss = 72.686554, step = 1501 (0.450 sec)
# INFO:tensorflow:global_step/sec: 232.541
# INFO:tensorflow:loss = 36.344944, step = 1601 (0.429 sec)
# INFO:tensorflow:global_step/sec: 247.506
# INFO:tensorflow:loss = 41.64475, step = 1701 (0.404 sec)
# INFO:tensorflow:global_step/sec: 224.702
# INFO:tensorflow:loss = 34.764225, step = 1801 (0.445 sec)
# INFO:tensorflow:global_step/sec: 237.513
# INFO:tensorflow:loss = 32.935463, step = 1901 (0.421 sec)
# INFO:tensorflow:global_step/sec: 236.389
# INFO:tensorflow:loss = 10.612389, step = 2001 (0.425 sec)
# INFO:tensorflow:global_step/sec: 238.076
# INFO:tensorflow:loss = 26.55315, step = 2101 (0.421 sec)
# INFO:tensorflow:global_step/sec: 272.461
# INFO:tensorflow:loss = 33.666725, step = 2201 (0.365 sec)
# INFO:tensorflow:global_step/sec: 261.077
# INFO:tensorflow:loss = 18.986326, step = 2301 (0.383 sec)
# INFO:tensorflow:global_step/sec: 243.291
# INFO:tensorflow:loss = 20.366932, step = 2401 (0.414 sec)
# INFO:tensorflow:global_step/sec: 272.46
# INFO:tensorflow:loss = 21.568905, step = 2501 (0.363 sec)
# INFO:tensorflow:global_step/sec: 264.53
# INFO:tensorflow:loss = 24.470263, step = 2601 (0.377 sec)
# INFO:tensorflow:global_step/sec: 263.138
# INFO:tensorflow:loss = 16.436003, step = 2701 (0.381 sec)
# INFO:tensorflow:global_step/sec: 302.086
# INFO:tensorflow:loss = 11.81592, step = 2801 (0.328 sec)
# INFO:tensorflow:global_step/sec: 273.209
# INFO:tensorflow:loss = 22.045597, step = 2901 (0.370 sec)
# INFO:tensorflow:global_step/sec: 252.507
# INFO:tensorflow:loss = 15.1362095, step = 3001 (0.394 sec)
# INFO:tensorflow:global_step/sec: 257.712
# INFO:tensorflow:loss = 15.416956, step = 3101 (0.389 sec)
# INFO:tensorflow:global_step/sec: 249.981
# INFO:tensorflow:loss = 23.133837, step = 3201 (0.401 sec)
# INFO:tensorflow:global_step/sec: 245.08
# INFO:tensorflow:loss = 10.693237, step = 3301 (0.405 sec)
# INFO:tensorflow:global_step/sec: 274.706
# INFO:tensorflow:loss = 13.471992, step = 3401 (0.367 sec)
# INFO:tensorflow:global_step/sec: 227.255
# INFO:tensorflow:loss = 29.739208, step = 3501 (0.441 sec)
# INFO:tensorflow:global_step/sec: 201.192
# INFO:tensorflow:loss = 7.8003206, step = 3601 (0.497 sec)
# INFO:tensorflow:global_step/sec: 230.93
# INFO:tensorflow:loss = 13.207682, step = 3701 (0.431 sec)
# INFO:tensorflow:global_step/sec: 281.669
# INFO:tensorflow:loss = 9.721252, step = 3801 (0.352 sec)
# INFO:tensorflow:global_step/sec: 279.308
# INFO:tensorflow:loss = 28.077976, step = 3901 (0.358 sec)
# INFO:tensorflow:global_step/sec: 273.951
# INFO:tensorflow:loss = 25.680935, step = 4001 (0.368 sec)
# INFO:tensorflow:global_step/sec: 236.39
# INFO:tensorflow:loss = 8.920834, step = 4101 (0.425 sec)
# INFO:tensorflow:global_step/sec: 218.803
# INFO:tensorflow:loss = 13.955862, step = 4201 (0.452 sec)
# INFO:tensorflow:global_step/sec: 256.392
# INFO:tensorflow:loss = 27.357212, step = 4301 (0.392 sec)
# INFO:tensorflow:global_step/sec: 263.833
# INFO:tensorflow:loss = 21.063866, step = 4401 (0.379 sec)
# INFO:tensorflow:global_step/sec: 272.459
# INFO:tensorflow:loss = 11.66723, step = 4501 (0.367 sec)
# INFO:tensorflow:global_step/sec: 276.987
# INFO:tensorflow:loss = 14.654037, step = 4601 (0.360 sec)
# INFO:tensorflow:global_step/sec: 280.878
# INFO:tensorflow:loss = 13.21742, step = 4701 (0.358 sec)
# INFO:tensorflow:global_step/sec: 248.121
# INFO:tensorflow:loss = 13.377468, step = 4801 (0.402 sec)
# INFO:tensorflow:global_step/sec: 225.208
# INFO:tensorflow:loss = 21.55287, step = 4901 (0.446 sec)
# INFO:tensorflow:global_step/sec: 228.293
# INFO:tensorflow:loss = 18.467873, step = 5001 (0.443 sec)
# INFO:tensorflow:global_step/sec: 244.482
# INFO:tensorflow:loss = 11.568766, step = 5101 (0.403 sec)
# INFO:tensorflow:global_step/sec: 259.72
# INFO:tensorflow:loss = 19.284733, step = 5201 (0.386 sec)
# INFO:tensorflow:global_step/sec: 255.083
# INFO:tensorflow:loss = 12.396652, step = 5301 (0.389 sec)
# INFO:tensorflow:global_step/sec: 273.953
# INFO:tensorflow:loss = 14.674174, step = 5401 (0.367 sec)
# INFO:tensorflow:global_step/sec: 266.648
# INFO:tensorflow:loss = 17.04018, step = 5501 (0.376 sec)
# INFO:tensorflow:global_step/sec: 280.878
# INFO:tensorflow:loss = 13.417972, step = 5601 (0.355 sec)
# INFO:tensorflow:global_step/sec: 276.988
# INFO:tensorflow:loss = 18.07029, step = 5701 (0.360 sec)
# INFO:tensorflow:global_step/sec: 277.757
# INFO:tensorflow:loss = 12.573042, step = 5801 (0.360 sec)
# INFO:tensorflow:global_step/sec: 288.996
# INFO:tensorflow:loss = 14.521128, step = 5901 (0.345 sec)
# INFO:tensorflow:global_step/sec: 276.988
# INFO:tensorflow:loss = 13.748209, step = 6001 (0.362 sec)
# INFO:tensorflow:global_step/sec: 292.376
# INFO:tensorflow:loss = 17.914524, step = 6101 (0.344 sec)
# INFO:tensorflow:global_step/sec: 277.757
# INFO:tensorflow:loss = 9.220093, step = 6201 (0.358 sec)
# INFO:tensorflow:global_step/sec: 283.266
# INFO:tensorflow:loss = 18.23307, step = 6301 (0.353 sec)
# INFO:tensorflow:global_step/sec: 274.704
# INFO:tensorflow:loss = 14.345911, step = 6401 (0.364 sec)
# INFO:tensorflow:global_step/sec: 290.677
# INFO:tensorflow:loss = 12.222195, step = 6501 (0.344 sec)
# INFO:tensorflow:global_step/sec: 288.162
# INFO:tensorflow:loss = 5.802264, step = 6601 (0.346 sec)
# INFO:tensorflow:global_step/sec: 282.466
# INFO:tensorflow:loss = 9.785373, step = 6701 (0.356 sec)
# INFO:tensorflow:global_step/sec: 270.25
# INFO:tensorflow:loss = 11.293001, step = 6801 (0.367 sec)
# INFO:tensorflow:global_step/sec: 266.647
# INFO:tensorflow:loss = 13.957825, step = 6901 (0.378 sec)
# INFO:tensorflow:global_step/sec: 282.464
# INFO:tensorflow:loss = 12.9440155, step = 7001 (0.352 sec)
# INFO:tensorflow:global_step/sec: 265.938
# INFO:tensorflow:loss = 12.524201, step = 7101 (0.377 sec)
# INFO:tensorflow:global_step/sec: 280.878
# INFO:tensorflow:loss = 26.998407, step = 7201 (0.356 sec)
# INFO:tensorflow:global_step/sec: 270.983
# INFO:tensorflow:loss = 12.432222, step = 7301 (0.369 sec)
# INFO:tensorflow:global_step/sec: 283.265
# INFO:tensorflow:loss = 24.999352, step = 7401 (0.354 sec)
# INFO:tensorflow:global_step/sec: 290.662
# INFO:tensorflow:loss = 12.445384, step = 7501 (0.343 sec)
# INFO:tensorflow:global_step/sec: 280.892
# INFO:tensorflow:loss = 15.859845, step = 7601 (0.356 sec)
# INFO:tensorflow:global_step/sec: 268.793
# INFO:tensorflow:loss = 11.793095, step = 7701 (0.373 sec)
# INFO:tensorflow:global_step/sec: 265.941
# INFO:tensorflow:loss = 8.378193, step = 7801 (0.375 sec)
# INFO:tensorflow:global_step/sec: 266.648
# INFO:tensorflow:loss = 13.035416, step = 7901 (0.376 sec)
# INFO:tensorflow:global_step/sec: 282.464
# INFO:tensorflow:loss = 9.001273, step = 8001 (0.354 sec)
# INFO:tensorflow:global_step/sec: 292.376
# INFO:tensorflow:loss = 13.178243, step = 8101 (0.342 sec)
# INFO:tensorflow:global_step/sec: 280.092
# INFO:tensorflow:loss = 11.368242, step = 8201 (0.355 sec)
# INFO:tensorflow:global_step/sec: 287.329
# INFO:tensorflow:loss = 9.632418, step = 8301 (0.349 sec)
# INFO:tensorflow:global_step/sec: 289.84
# INFO:tensorflow:loss = 13.987578, step = 8401 (0.343 sec)
# INFO:tensorflow:global_step/sec: 294.096
# INFO:tensorflow:loss = 13.155195, step = 8501 (0.342 sec)
# INFO:tensorflow:global_step/sec: 285.693
# INFO:tensorflow:loss = 12.331309, step = 8601 (0.351 sec)
# INFO:tensorflow:global_step/sec: 288.996
# INFO:tensorflow:loss = 13.822488, step = 8701 (0.345 sec)
# INFO:tensorflow:global_step/sec: 287.334
# INFO:tensorflow:loss = 15.856646, step = 8801 (0.346 sec)
# INFO:tensorflow:global_step/sec: 283.266
# INFO:tensorflow:loss = 10.970135, step = 8901 (0.355 sec)
# INFO:tensorflow:global_step/sec: 285.694
# INFO:tensorflow:loss = 7.420175, step = 9001 (0.351 sec)
# INFO:tensorflow:global_step/sec: 289.833
# INFO:tensorflow:loss = 11.108641, step = 9101 (0.344 sec)
# INFO:tensorflow:global_step/sec: 280.878
# INFO:tensorflow:loss = 11.875462, step = 9201 (0.356 sec)
# INFO:tensorflow:global_step/sec: 282.465
# INFO:tensorflow:loss = 13.209287, step = 9301 (0.355 sec)
# INFO:tensorflow:global_step/sec: 282.464
# INFO:tensorflow:loss = 9.1613455, step = 9401 (0.354 sec)
# INFO:tensorflow:global_step/sec: 287.324
# INFO:tensorflow:loss = 5.8079023, step = 9501 (0.347 sec)
# INFO:tensorflow:global_step/sec: 287.346
# INFO:tensorflow:loss = 12.676117, step = 9601 (0.350 sec)
# INFO:tensorflow:global_step/sec: 297.597
# INFO:tensorflow:loss = 8.686282, step = 9701 (0.333 sec)
# INFO:tensorflow:global_step/sec: 288.164
# INFO:tensorflow:loss = 16.976477, step = 9801 (0.348 sec)
# INFO:tensorflow:global_step/sec: 285.693
# INFO:tensorflow:loss = 13.820668, step = 9901 (0.351 sec)
# INFO:tensorflow:Saving checkpoints for 10000 into C:\Users\Douglas\AppData\Local\Temp\tmp2ybqnd2z\model.ckpt.
# INFO:tensorflow:Loss for final step: 10.776202.

# %%
funcao_teste = tf.estimator.inputs.pandas_input_fn(x = x_teste, y = y_teste, batch_size = 32,
                                                  num_epochs = 1, shuffle = False)

# %%
classificador.evaluate(input_fn = funcao_teste)
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Entity <bound method _DNNModel.call of <tensorflow_estimator.python.estimator.canned.dnn._DNNModel object at 0x000001F87805AAC8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method _DNNModel.call of <tensorflow_estimator.python.estimator.canned.dnn._DNNModel object at 0x000001F87805AAC8>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method _DNNModel.call of <tensorflow_estimator.python.estimator.canned.dnn._DNNModel object at 0x000001F87805AAC8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method _DNNModel.call of <tensorflow_estimator.python.estimator.canned.dnn._DNNModel object at 0x000001F87805AAC8>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method DenseFeatures.call of <tensorflow.python.feature_column.feature_column_v2.DenseFeatures object at 0x000001F800684CC8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method DenseFeatures.call of <tensorflow.python.feature_column.feature_column_v2.DenseFeatures object at 0x000001F800684CC8>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method DenseFeatures.call of <tensorflow.python.feature_column.feature_column_v2.DenseFeatures object at 0x000001F800684CC8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method DenseFeatures.call of <tensorflow.python.feature_column.feature_column_v2.DenseFeatures object at 0x000001F800684CC8>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001F8004B7288>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001F8004B7288>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001F8004B7288>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001F8004B7288>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001F8004B7888>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001F8004B7888>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001F8004B7888>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001F8004B7888>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001F87A60DBC8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001F87A60DBC8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001F87A60DBC8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001F87A60DBC8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-08-13T14:51:26Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\Douglas\AppData\Local\Temp\tmp2ybqnd2z\model.ckpt-10000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2020-08-13-14:51:29
# INFO:tensorflow:Saving dict for global step 10000: accuracy = 0.82853925, accuracy_baseline = 0.7602621, auc = 0.88880885, auc_precision_recall = 0.72284, average_loss = 0.35656282, global_step = 10000, label/mean = 0.23973794, loss = 11.38321, precision = 0.6481564, prediction/mean = 0.28865027, recall = 0.62297183
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 10000: C:\Users\Douglas\AppData\Local\Temp\tmp2ybqnd2z\model.ckpt-10000
# {'accuracy': 0.82853925,
#  'accuracy_baseline': 0.7602621,
#  'auc': 0.88880885,
#  'auc_precision_recall': 0.72284,
#  'average_loss': 0.35656282,
#  'label/mean': 0.23973794,
#  'loss': 11.38321,
#  'precision': 0.6481564,
#  'prediction/mean': 0.28865027,
#  'recall': 0.62297183,
#  'global_step': 10000}

# %%
## TODO: APLICAR NORMALIZACAO/PADRONIZACAO PARA MELHORAR OS RESULTADOS (AULA 62)
