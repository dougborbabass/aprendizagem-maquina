# %%
import tensorflow as tf
import numpy as np
import pandas as pd

# %%
base = pd.read_csv('test.csv')

# %%
base.head()
# Out:
#    Amostra 1  Amostra 2  Amostra 3  Amostra 4  Amostra 5  Amostra 6  \
# 0        0.0      0.063      0.125      0.187      0.249      0.309
# 1        0.0      0.126      0.251      0.375      0.497      0.618
# 2        0.0      0.251      0.501      0.750      0.995      1.236
# 3        0.0      0.502      1.003      1.499      1.990      2.472
# 4        0.0      0.628      1.253      1.874      2.487      3.090
#
#    Amostra 7  Amostra 8  Amostra 9  Amostra 10  ...  Amostra 93  Amostra 94  \
# 0      0.368      0.426      0.482       0.536  ...      -0.482      -0.426
# 1      0.736      0.852      0.964       1.072  ...      -0.964      -0.852
# 2      1.472      1.703      1.927       2.143  ...      -1.927      -1.703
# 3      2.945      3.406      3.854       4.287  ...      -3.854      -3.406
# 4      3.681      4.258      4.818       5.358  ...      -4.818      -4.258
#
#    Amostra 95  Amostra 96  Amostra 97  Amostra 98  Amostra 99  Amostra 100  \
# 0      -0.368      -0.309      -0.249      -0.187      -0.125       -0.063
# 1      -0.736      -0.618      -0.497      -0.375      -0.251       -0.126
# 2      -1.472      -1.236      -0.995      -0.750      -0.501       -0.251
# 3      -2.945      -2.472      -1.990      -1.499      -1.003       -0.502
# 4      -3.681      -3.090      -2.487      -1.874      -1.253       -0.628
#
#    Amostra 101  Forma de onda
# 0          0.0            1.0
# 1          0.0            1.0
# 2          0.0            1.0
# 3          0.0            1.0
# 4          0.0            1.0
#
# [5 rows x 102 columns]

# %%
base.shape
# Out:
# (5, 102)

# %%
x = base.drop('Forma de onda', axis=1) # atributos previsores
x
# Out:
#    Amostra 1  Amostra 2  Amostra 3  Amostra 4  Amostra 5  Amostra 6  \
# 0        0.0      0.063      0.125      0.187      0.249      0.309
# 1        0.0      0.126      0.251      0.375      0.497      0.618
# 2        0.0      0.251      0.501      0.750      0.995      1.236
# 3        0.0      0.502      1.003      1.499      1.990      2.472
# 4        0.0      0.628      1.253      1.874      2.487      3.090
#
#    Amostra 7  Amostra 8  Amostra 9  Amostra 10  ...  Amostra 92  Amostra 93  \
# 0      0.368      0.426      0.482       0.536  ...      -0.536      -0.482
# 1      0.736      0.852      0.964       1.072  ...      -1.072      -0.964
# 2      1.472      1.703      1.927       2.143  ...      -2.143      -1.927
# 3      2.945      3.406      3.854       4.287  ...      -4.287      -3.854
# 4      3.681      4.258      4.818       5.358  ...      -5.358      -4.818
#
#    Amostra 94  Amostra 95  Amostra 96  Amostra 97  Amostra 98  Amostra 99  \
# 0      -0.426      -0.368      -0.309      -0.249      -0.187      -0.125
# 1      -0.852      -0.736      -0.618      -0.497      -0.375      -0.251
# 2      -1.703      -1.472      -1.236      -0.995      -0.750      -0.501
# 3      -3.406      -2.945      -2.472      -1.990      -1.499      -1.003
# 4      -4.258      -3.681      -3.090      -2.487      -1.874      -1.253
#
#    Amostra 100  Amostra 101
# 0       -0.063          0.0
# 1       -0.126          0.0
# 2       -0.251          0.0
# 3       -0.502          0.0
# 4       -0.628          0.0
#
# [5 rows x 101 columns]

# %%
y = base.iloc[:,-1] # pegando a ultima coluna para saber qual a classe
y
# Out:
# 0    1.0
# 1    1.0
# 2    1.0
# 3    1.0
# 4    1.0
# Name: Forma de onda, dtype: float64
